# %%
data = '...'

# %%
k = 11
L = 578
t = 16

# %%
from collections import Counter
answer = set()

# %%
for i in range(len(data)-L+1):
    d = Counter()
    
    for j in range(i+L-k+1):
        d[data[j:j+k]] += 1
        
    for elem in d.elements():
        if d[elem] >= t: answer.add(elem)

# %%
str_ans = ''
for elem in answer:
    str_ans += elem + ' '

# %%
print(str_ans)
# Out:
# ATTGAGACTTC AAGGGGGCGTG TCCACGACGCC CCCCACTAAAG ACAAGTTTAAA GTTCCGACCCG
